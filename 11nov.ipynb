# %% [markdown]
# ### <a id='Getting Data Ready2'>1. Getting Data Ready</a>

# %%
import pandas as pd
import json
import re
pd.set_option("display.max_columns",2500)
pd.set_option("display.max_rows",2500)

# %%
from google.colab import drive
drive.mount('/content/drive') # mounting drive in each runtime
try:
    #data = pd.read_csv('E:\yearproject.csv')
    data=pd.read_csv('/content/drive/My Drive/FY_project/dataset/results-20190513-ofapr19.csv')
    print('File successfully loaded into the DataFrame..')
except:
    print("File not found...")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# File successfully loaded into the DataFrame..

# %%
data.columns
# Out:
# Index(['action', 'url', 'title', 'body', 'labels'], dtype='object')

# %%
data.count()
# Out:
# action    7964
# url       7964
# title     7964
# body      7920
# labels    7964
# dtype: int64

# %%
data.head(3)
# Out:
#      action  ...                                             labels
# 0  "closed"  ...  [{"id":455857191,"node_id":"MDU6TGFiZWw0NTU4NT...
# 1  "closed"  ...  [{"id":312160661,"node_id":"MDU6TGFiZWwzMTIxNj...
# 2  "closed"  ...                                                 []
#
# [3 rows x 5 columns]

# %%
data.shape
# Out:
# (7964, 5)

# %% [markdown]
# ### <a id='Data Cleaning and Munging'>2. Data Cleaning and Munging</a>

# %%
print("Null values in:")
data.isnull().sum()
# Out:
# Null values in:
# action     0
# url        0
# title      0
# body      44
# labels     0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (7920, 5)

# %% [markdown]
# ### 3.2 Dealing with duplicates in the data set

# %%
print('The no. of duplicates in the data are',data.duplicated().sum())
# Out:
# The no. of duplicates in the data are 3

# %%
data.drop_duplicates(inplace=True)

# %%
data.isnull().sum()
# Out:
# action    0
# url       0
# title     0
# body      0
# labels    0
# dtype: int64

# %%
data.shape
# Out:
# (7917, 5)

# %% [markdown]
# ### <a id='Data Analysis'>2. Data Analysis</a>

# %%
closed=data[data['action']=="\"closed\""]
len(closed)
# Out:
# 7917

# %% [markdown]
# **ALL CLOSED ISSUES**

# %%
#Removing url and action columns
data=data[["title","body","labels"]]

# %%
labeled=data[data['labels']!='[]']
unlabeled=data[data['labels']=='[]']

# %%
labeled.shape
# Out:
# (4063, 3)

# %%
unlabeled.shape
# Out:
# (3854, 3)

# %%
labeled.head()
# Out:
#                                                title  ...                                             labels
# 0  "Error: Building package zlib:x64-windows-stat...  ...  [{"id":455857191,"node_id":"MDU6TGFiZWw0NTU4NT...
# 1             "Pagination bug when removing an item"  ...  [{"id":312160661,"node_id":"MDU6TGFiZWwzMTIxNj...
# 4            "Helm podAntiAffinity templating error"  ...  [{"id":670442116,"node_id":"MDU6TGFiZWw2NzA0ND...
# 5  "[0.5][Tradingview] Quick Chart resize does no...  ...  [{"id":1089646255,"node_id":"MDU6TGFiZWwxMDg5N...
# 6                                    "Upgrade isort"  ...  [{"id":717069763,"node_id":"MDU6TGFiZWw3MTcwNj...
#
# [5 rows x 3 columns]

# %%
json.loads(labeled['labels'][5])
# Out:
# [{'color': 'b8e4fc',
#   'default': False,
#   'id': 1089646255,
#   'name': '[1b] User Story',
#   'node_id': 'MDU6TGFiZWwxMDg5NjQ2MjU1',
#   'url': 'https://api.github.com/repos/bitshares/bitshares-ui/labels/[1b]%20User%20Story'},
#  {'color': 'b60205',
#   'default': False,
#   'id': 272058720,
#   'name': '[3] Bug',
#   'node_id': 'MDU6TGFiZWwyNzIwNTg3MjA=',
#   'url': 'https://api.github.com/repos/bitshares/bitshares-ui/labels/[3]%20Bug'},
#  {'color': 'fbca04',
#   'default': False,
#   'id': 522016380,
#   'name': '[4c] High Priority',
#   'node_id': 'MDU6TGFiZWw1MjIwMTYzODA=',
#   'url': 'https://api.github.com/repos/bitshares/bitshares-ui/labels/[4c]%20High%20Priority'},
#  {'color': 'f9aed0',
#   'default': False,
#   'id': 1089668332,
#   'name': '[5a] Tiny',
#   'node_id': 'MDU6TGFiZWwxMDg5NjY4MzMy',
#   'url': 'https://api.github.com/repos/bitshares/bitshares-ui/labels/[5a]%20Tiny'},
#  {'color': '0052cc',
#   'default': False,
#   'id': 1133046734,
#   'name': '[6] RC Blockage',
#   'node_id': 'MDU6TGFiZWwxMTMzMDQ2NzM0',
#   'url': 'https://api.github.com/repos/bitshares/bitshares-ui/labels/[6]%20RC%20Blockage'},
#  {'color': '994d00',
#   'default': False,
#   'id': 1134524965,
#   'name': '[7] Estimated',
#   'node_id': 'MDU6TGFiZWwxMTM0NTI0OTY1',
#   'url': 'https://api.github.com/repos/bitshares/bitshares-ui/labels/[7]%20Estimated'}]

# %%
#converting string to dict
[x['name'] for x in json.loads(labeled['labels'][5])]
# Out:
# ['[1b] User Story',
#  '[3] Bug',
#  '[4c] High Priority',
#  '[5a] Tiny',
#  '[6] RC Blockage',
#  '[7] Estimated']

# %%
labels=[]
for i in labeled['labels']:
    labels.append([x['name'] for x in json.loads(i)])
labeled['labels']=labels
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
import string
import nltk
#from nltk.corpus import stopwords  # corpus means collection of writings
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
print(len(stopwords.words('english')))
# Out:
# 179

# %%
stopword=stopwords.words('english')
stopword[:5]
# Out:
# ['i', 'me', 'my', 'myself', 'we']

# %%
newStopWords = ['www','com','r','n','c','e','f','b','g','h','l','http','https','u','v','x','z','de','non','rb','ef']
stopword.extend(newStopWords)

# %%
def clean_text(s):
    s=re.sub("[\'\"]","",s) #remove '' and ""
    s=re.sub("\\\\r","",s)  #remove \r
    s=re.sub("\\\\n","",s)  #remove \n
    s=re.sub("[^a-zA-Z]"," ",s) #remove everything but letters
    s=''.join([char for char in s if char not in string.punctuation]) #remove all punctuations
    l=[word.lower() for word in s.split() if not word.lower() in stopword]  #remove stopwords
    return ' '.join(l)

# %%
labeled['title'] = labeled['title'].apply(lambda x: clean_text(x))
labeled['body'] = labeled['body'].apply(lambda x: clean_text(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
labeled.head()
# Out:
#                                                title  ...                                             labels
# 0  error building package zlib windows static fai...  ...                                      [needs-repro]
# 1                       pagination bug removing item  ...                                      [enhancement]
# 4              helm podantiaffinity templating error  ...                                [area/environments]
# 5  tradingview quick chart resize honor limit values  ...  [[1b] User Story, [3] Bug, [4c] High Priority,...
# 6                                      upgrade isort  ...  [feature-refactoring, good first issue, needs ...
#
# [5 rows x 3 columns]

# %%
def clean_label(l):
    s=','.join(l)
    s=re.sub("[\[\\]]",'',s)
    s=re.sub("['0123456789']",'',s)
    s=''.join([char.lower() for char in s])
    st=[]
    for com in s.split(','):
        l=[]
        for wo in com.split():
            if not wo in ['r','c','b','rc','a','l','x','z',':','p:']:
                l.append(wo)
        st.append(' '.join(l))
    return ','.join(st)

# %%
labeled['try']=labeled['labels'].apply(lambda x: clean_label(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
labeled
# Out:
#                                                   title  \
# 0     error building package zlib windows static fai...
# 1                          pagination bug removing item
# 4                 helm podantiaffinity templating error
# 5     tradingview quick chart resize honor limit values
# 6                                         upgrade isort
# ...                                                 ...
# 7957                 review uri endpoints make cohesive
# 7959                       finer audio controls tangent
# 7960                                composer auth saved
# 7961                                        slide macro
# 7963        change bias question answer width summaries
#
#                                                    body  \
# 0        package zlib windows staticvcpkg version debug
# 1     reported pro user exemple table items per page...
# 4     describe bug helm charts fail generate proper ...
# 5     describe bug arrows tradingview chart size don...
# 6     using isort pypi org project isort latest migh...
# ...                                                 ...
# 7957
# 7959  mike lunt writes feature would like see implem...
# 7960  everytime reboot docker images auth json file ...
# 7961  based work github threefoldtech jumpscalex tre...
# 7963  move answer summary providing space question c...
#
#                                                  labels  \
# 0                                         [needs-repro]
# 1                                         [enhancement]
# 4                                   [area/environments]
# 5     [[1b] User Story, [3] Bug, [4c] High Priority,...
# 6     [feature-refactoring, good first issue, needs ...
# ...                                                 ...
# 7957                                      [in progress]
# 7959                                      [enhancement]
# 7960                                      [enhancement]
# 7961                 [state_verification, type_feature]
# 7963                                      [enhancement]
#
#                                                     try
# 0                                           needs-repro
# 1                                           enhancement
# 4                                     area/environments
# 5     user story,bug,high priority,tiny,blockage,est...
# 6     feature-refactoring,good first issue,needs pr,...
# ...                                                 ...
# 7957                                        in progress
# 7959                                        enhancement
# 7960                                        enhancement
# 7961                    state_verification,type_feature
# 7963                                        enhancement
#
# [4063 rows x 4 columns]

# %%
labels=[]
for i in labeled['try']:
    for com in i.split(','):
        labels.append(''.join(com))

# %%
import collections
count=dict()
for x in labels:
    if x not in count:
        count[x]=1
    else:
        count[x]+=1
d = collections.Counter(count)

# %%
i=0
for w,c in d.most_common(2767):
    i+=1
print("unique labels =",i)
# Out:
# unique labels = 2767

# %%
freq=dict()
for w,c in d.most_common(2767):
    freq[w]=c

# %%
freq
# Out:
# {'bug': 731,
#  'enhancement': 606,
#  'question': 157,
#  'help wanted': 106,
#  'good first issue': 89,
#  'feature': 80,
#  'wontfix': 75,
#  'type: bug': 50,
#  'stale': 50,
#  'p': 48,
#  'greenkeeper': 47,
#  'in progress': 43,
#  'triaged': 42,
#  'documentation': 38,
#  'task': 36,
#  'medium': 36,
#  'duplicate': 35,
#  'invalid': 30,
#  'kind/bug': 29,
#  'feature request': 26,
#  'docs': 25,
#  'user-submission': 25,
#  'high priority': 23,
#  'priority: high': 23,
#  'ui': 23,
#  'assigned-to-author': 23,
#  'type: enhancement': 22,
#  'priority: medium': 22,
#  'review': 21,
#  '': 21,
#  'design': 19,
#  'high': 19,
#  'n: adguard browser extension': 18,
#  'frontend': 18,
#  'epic': 18,
#  'support': 17,
#  'fixed': 17,
#  'browser-firefox': 17,
#  'backend': 15,
#  'priority/p': 15,
#  'new-version': 14,
#  'cxp': 14,
#  'triage': 14,
#  'critical': 14,
#  'browser-firefox-mobile': 14,
#  'discussion': 13,
#  'sprint': 13,
#  'version/.': 13,
#  '.': 13,
#  'doc-enhancement': 12,
#  'approved': 12,
#  'eps': 11,
#  'in scope (june )': 11,
#  'backlog': 11,
#  'target/..': 11,
#  'lang/zh': 11,
#  'priority: low': 11,
#  'resolved': 11,
#  'kind/feature': 11,
#  'todo': 11,
#  'a: resolved': 11,
#  'gitalk': 11,
#  'ver: ..': 11,
#  'low': 10,
#  'front end': 10,
#  'doc-bug': 10,
#  'scan:--': 10,
#  'priority.medium': 10,
#  'a: cannot reproduce': 10,
#  't: annoyance': 10,
#  'type: question': 10,
#  'api': 10,
#  'needs more info': 10,
#  'security vulnerability': 10,
#  'product-question': 10,
#  'improvement': 9,
#  'ios': 9,
#  't: anti adblock script': 9,
#  'sync/new': 9,
#  'nsfw': 9,
#  'type:support': 9,
#  'new-review': 9,
#  'v..': 9,
#  'type:bug': 9,
#  'priority': 9,
#  'windows': 9,
#  'mvp': 9,
#  'ui/ux': 9,
#  'priority-critical': 9,
#  'type bug': 9,
#  'proposal': 9,
#  'user story': 8,
#  'needs pr': 8,
#  'low priority': 8,
#  'new feature': 8,
#  'easy': 8,
#  'type: bug 🐛': 8,
#  'urgent': 8,
#  'n: adguard for windows': 8,
#  'blocked': 8,
#  'android': 8,
#  'blocker': 8,
#  'framework': 8,
#  'priority-normal': 8,
#  'inactive': 8,
#  't: ads': 8,
#  'ships-in-future-update': 8,
#  'type: feature': 8,
#  'in-progress': 8,
#  'investigate': 8,
#  'accepted': 8,
#  'project: website': 8,
#  '🐞 bug': 8,
#  'client': 7,
#  'medium priority': 7,
#  'fixed in dev': 7,
#  'build': 7,
#  't: incorrect blocking': 7,
#  'ux': 7,
#  'gssoc': 7,
#  'ready': 7,
#  'priority: critical': 7,
#  'testing': 7,
#  'type: dev :robot:': 7,
#  'regression': 7,
#  'priority-important': 7,
#  'priority: p': 7,
#  'to do': 7,
#  'normal': 7,
#  'project': 7,
#  'auto-migrated': 7,
#  'sf-archive': 7,
#  'priority - high': 6,
#  'devops': 6,
#  'spike': 6,
#  'area-mvc': 6,
#  'ready for retest': 6,
#  'priority/high': 6,
#  'kind/question': 6,
#  'past--days': 6,
#  'lifecycle/rotten': 6,
#  'affects_.': 6,
#  'q': 6,
#  'severity.medium': 6,
#  'type.bug': 6,
#  'in review': 6,
#  'type: regression': 6,
#  'pending': 6,
#  'security': 6,
#  'priority.high': 6,
#  'core': 6,
#  '..': 6,
#  'topic:core': 6,
#  'performance': 6,
#  'front-end': 6,
#  'active-directory/svc': 6,
#  'mds': 6,
#  'type: refactor': 5,
#  'suggestion': 5,
#  'production': 5,
#  'type.story': 5,
#  'usability': 5,
#  'current sprint': 5,
#  'validation': 5,
#  'back-end': 5,
#  'stale?': 5,
#  'fixed confirmed': 5,
#  'type:enhancement': 5,
#  'stat:awaiting response': 5,
#  'type:bug/performance': 5,
#  'needs investigation': 5,
#  'python': 5,
#  'major': 5,
#  'th': 5,
#  'priority-': 5,
#  'refactoring': 5,
#  'request-for-external': 5,
#  'javascript': 5,
#  'lifecycle/stale': 5,
#  'crash': 5,
#  'refactor': 5,
#  't: bug': 5,
#  'confirmed': 5,
#  'tango': 5,
#  'upstream': 5,
#  'v.x': 5,
#  'c-bug': 5,
#  'has pr': 5,
#  'needs-repro': 4,
#  'c-enhancement': 4,
#  'tests': 4,
#  'error:crash': 4,
#  'easy fix': 4,
#  'breaking change': 4,
#  'important': 4,
#  'type/bug': 4,
#  'component': 4,
#  'content': 4,
#  'v.': 4,
#  'release bug': 4,
#  'homework': 4,
#  'css': 4,
#  'infrastructure': 4,
#  'status: resolved': 4,
#  '. needs triage': 4,
#  'programming': 4,
#  'sig/scheduling': 4,
#  'severe: crash': 4,
#  'ops': 4,
#  'bounty': 4,
#  'minor': 4,
#  'area-system.net.http.socketshttphandler': 4,
#  'type: documentation': 4,
#  'n: adguard for ios': 4,
#  'major city': 4,
#  'kind/enhancement': 4,
#  'tide/merge-blocker': 4,
#  'bug :bug:': 4,
#  'component/ui': 4,
#  'comp:ops': 4,
#  'f: material design': 4,
#  'area/ci': 4,
#  'area/cli': 4,
#  'good-first-issue': 4,
#  'data': 4,
#  'type-bug': 4,
#  'defect': 4,
#  'arendus: back-end': 4,
#  'needs info': 4,
#  'type: maintenance': 4,
#  'v': 4,
#  'category: core': 4,
#  'doc feedback': 4,
#  'topic:editor': 4,
#  'need more info': 4,
#  'status/resolved': 4,
#  'status/triaged': 4,
#  'reporting': 4,
#  'bug :beetle:': 4,
#  '...': 4,
#  'done': 4,
#  'team': 4,
#  'need approval': 4,
#  'version ..': 4,
#  'status/ready-for-review': 4,
#  'type:feature': 4,
#  'week': 4,
#  'brak_odpowiedzi': 4,
#  'type-code health': 3,
#  'priority:low': 3,
#  'priority:high': 3,
#  'training': 3,
#  'state_verification': 3,
#  'type_bug': 3,
#  'app: projects': 3,
#  '🐛 bug': 3,
#  'server': 3,
#  'service bus': 3,
#  'large': 3,
#  'status: in progress': 3,
#  'code': 3,
#  'packaging': 3,
#  'type.task': 3,
#  '- in review': 3,
#  'waiting for feedback': 3,
#  'needs review': 3,
#  'community': 3,
#  'tech debt': 3,
#  'linux': 3,
#  'welcome': 3,
#  'investigating': 3,
#  'plugin': 3,
#  'branding': 3,
#  'patch': 3,
#  'yaml content request': 3,
#  'script': 3,
#  'art': 3,
#  'gas': 3,
#  'support:core': 3,
#  'type: docs': 3,
#  'type-enhancement': 3,
#  'priority/important': 3,
#  '- ready': 3,
#  'priority - medium': 3,
#  'repo settings': 3,
#  'document': 3,
#  'sprint day': 3,
#  'data import': 3,
#  'merged': 3,
#  'development': 3,
#  'scheduled': 3,
#  'type: spec': 3,
#  'product feedback': 3,
#  'committed': 3,
#  'demo': 3,
#  'event-request': 3,
#  'os:windows': 3,
#  'fixed in next update': 3,
#  'status: available': 3,
#  'low hanging fruit': 3,
#  'i: needs triage': 3,
#  'bug bash': 3,
#  'sf': 3,
#  'area-codegen': 3,
#  'tier': 3,
#  'pinned': 3,
#  'compatibility': 3,
#  'tarea': 3,
#  'requirements ready': 3,
#  'state dept.': 3,
#  't: defect': 3,
#  'source - docs.ms': 3,
#  'status.ongoing': 3,
#  'p-': 3,
#  'new release': 3,
#  'type - bug report': 3,
#  'sig/storage': 3,
#  'tenet-compatibility': 3,
#  'needs discussion': 3,
#  'type: bug :bug:': 3,
#  'mobile': 3,
#  'database': 3,
#  '-- :: + cst': 3,
#  'icebox': 3,
#  'macos': 3,
#  ':beetle: bug :beetle:': 3,
#  'nes': 3,
#  'pulsetile-ra': 3,
#  'state: fixed': 3,
#  'test': 3,
#  'area/ui': 3,
#  'more-info-required': 3,
#  'admin': 3,
#  'status/to-test': 3,
#  'team/ca': 3,
#  'pf website issue': 3,
#  'compliment': 3,
#  'type: enhancement ✨': 3,
#  'meta': 3,
#  'backend:tensorflow': 3,
#  'feature-request': 3,
#  'status: waiting-for-reply': 3,
#  'difficulty: medium': 3,
#  'topic:gdscript': 3,
#  '*caused-by-extension': 3,
#  'solved': 3,
#  'zube: in review': 3,
#  'next release': 3,
#  't: enhancement': 3,
#  'to be closed': 3,
#  'caseflow-hearing-schedule': 3,
#  'browser-focus-geckoview': 3,
#  'kind/test failure': 3,
#  'sp:': 3,
#  'feat': 3,
#  'kind/bug-qa': 3,
#  '.-stable': 3,
#  'model': 3,
#  '- task': 3,
#  'group': 3,
#  'storage/svc': 3,
#  'size:s': 3,
#  'dependency': 3,
#  'translation': 3,
#  'ci/cd': 3,
#  'future build': 3,
#  'type: question or discussion': 3,
#  'more info needed': 3,
#  'tech-improvement-backlog': 3,
#  'v :new:': 3,
#  'docker': 3,
#  'editorial': 3,
#  'calibration request': 3,
#  'site-recovery/svc': 3,
#  'arch-arm': 3,
#  'apitestuat': 2,
#  'compiler': 2,
#  'backport': 2,
#  'tool': 2,
#  'cgmes': 2,
#  'prio:high': 2,
#  'area-servers': 2,
#  'customer': 2,
#  'chore': 2,
#  'view': 2,
#  'профильподготовки': 2,
#  'engine': 2,
#  'documentação': 2,
#  'po': 2,
#  'issue': 2,
#  'optimization': 2,
#  'bug report': 2,
#  'editor': 2,
#  'unity': 2,
#  'client management': 2,
#  'size': 2,
#  'component: core': 2,
#  'smart contracts': 2,
#  'more-info-needed': 2,
#  'shop': 2,
#  'needsfix': 2,
#  'area/replication': 2,
#  'sync/update': 2,
#  'gemensam': 2,
#  'needs-priority': 2,
#  'difficulty:moderate': 2,
#  'service-fabric/svc': 2,
#  'type: improvement': 2,
#  'management': 2,
#  'audio': 2,
#  'intellij': 2,
#  'logistics': 2,
#  'improvements': 2,
#  'tengo un error': 2,
#  'debug': 2,
#  'html/css': 2,
#  'prioritary': 2,
#  '功能实现': 2,
#  'answered': 2,
#  'implemented': 2,
#  'react': 2,
#  'unscheduled': 2,
#  'data science': 2,
#  'beginner': 2,
#  'new api': 2,
#  ':infrastructure': 2,
#  'metricbeat': 2,
#  'liveshare': 2,
#  '用户测试': 2,
#  'db': 2,
#  'fix pending': 2,
#  'verified': 2,
#  'type:documentation': 2,
#  'project: components': 2,
#  'source issue': 2,
#  'priority/low': 2,
#  'a-impl-trait': 2,
#  'status stale': 2,
#  'status/stale': 2,
#  'important and urgent': 2,
#  'hashmap': 2,
#  'type: new feature': 2,
#  'csd.': 2,
#  'type: system': 2,
#  'asana': 2,
#  'issue: format is valid': 2,
#  'pr submitted': 2,
#  'in': 2,
#  'feature-*': 2,
#  'pr open': 2,
#  'need feedback': 2,
#  'status: in review': 2,
#  'needs-info': 2,
#  'status: ready for release': 2,
#  'r.-dom-cur-test': 2,
#  'gv': 2,
#  'priority/medium': 2,
#  'component: table': 2,
#  'severity: medium': 2,
#  'version: ..x': 2,
#  '..-alpha': 2,
#  'developed': 2,
#  'c++': 2,
#  'auto': 2,
#  'gui': 2,
#  'i: bug': 2,
#  'architect': 2,
#  'type: help wanted 🤷\u200d♂️': 2,
#  'network': 2,
#  'd-lite': 2,
#  'keyboard': 2,
#  'visualization': 2,
#  'more information needed': 2,
#  'dev': 2,
#  'cat/enhancement': 2,
#  'notif/triage': 2,
#  'subj: ui/ux': 2,
#  'feature/rewards': 2,
#  'high-priority': 2,
#  'c: code generation': 2,
#  'e: all editions': 2,
#  'r: fixed': 2,
#  ':watch: not triaged': 2,
#  'semantic-release': 2,
#  'analytics': 2,
#  'pending-close-response-required': 2,
#  'breaking-change': 2,
#  'type: process': 2,
#  'needs repro': 2,
#  'change': 2,
#  'hasfix': 2,
#  'pr - ready to be committed': 2,
#  'status - has pull request': 2,
#  't - enhancement': 2,
#  'area-compilers': 2,
#  'new language feature - nullable reference types': 2,
#  '\U0001f9ea testing': 2,
#  'interface': 2,
#  'for: up for grabs': 2,
#  'arendus: front-end': 2,
#  'c-test-failure': 2,
#  'o-robot': 2,
#  'area/auth-integration': 2,
#  'triple integration 🔱': 2,
#  'incomplete': 2,
#  'type: not bug': 2,
#  'p-medium': 2,
#  'status: needs triage': 2,
#  'sprint one': 2,
#  'backport .': 2,
#  'bot': 2,
#  'low effort': 2,
#  'fix proposed': 2,
#  'resolved: next release': 2,
#  '-april': 2,
#  'fc-redirect-technical': 2,
#  'waiting for review': 2,
#  'io': 2,
#  ':grey_exclamation: priority low': 2,
#  'priority-high': 2,
#  'status: defined': 2,
#  'status: wontfix': 2,
#  'area - code analysis': 2,
#  'mac': 2,
#  'type: security': 2,
#  'bugbash': 2,
#  'issue-discussion': 2,
#  'vsts': 2,
#  'data-factory/svc': 2,
#  'backtrace.io': 2,
#  ':books: area - c# guide': 2,
#  'qa/pass': 2,
#  'product-issue': 2,
#  't - feature': 2,
#  'helpdesk': 2,
#  'source: offline chat': 2,
#  'rc.': 2,
#  'bug/-confirmed': 2,
#  'user experience': 2,
#  'could close': 2,
#  'status: review needed': 2,
#  '>bug': 2,
#  'priority:medium': 2,
#  'type:project-task': 2,
#  'orange': 2,
#  'wip': 2,
#  'c/cli': 2,
#  'story': 2,
#  'cleanup': 2,
#  'm-low': 2,
#  'epic historie- en versiebeheer (sprint )': 2,
#  'prio h': 2,
#  'component:arc': 2,
#  'auth': 2,
#  'stat:awaiting tensorflower': 2,
#  'typing': 2,
#  '--x': 2,
#  'typescript': 2,
#  'construction': 2,
#  'support request': 2,
#  'version/..': 2,
#  'helm': 2,
#  'todo :spiral_notepad:': 2,
#  'severity.low': 2,
#  'new': 2,
#  'ep request': 2,
#  'status: abandoned': 2,
#  'platform: ios': 2,
#  'type: accepted/bug': 2,
#  'area:usecases': 2,
#  'state_inprogress': 2,
#  'wanted': 2,
#  'no triage': 2,
#  'doublechecked': 2,
#  'bo': 2,
#  'type enhancement': 2,
#  'f-enhancement 🎁': 2,
#  'pri: - required': 2,
#  'orion reviewed': 2,
#  'layout': 2,
#  'area: artifacts': 2,
#  'http': 2,
#  'pf': 2,
#  'inbox': 2,
#  'user': 2,
#  'period/.': 2,
#  'type: issue': 2,
#  'c: core': 2,
#  'kind/documentation': 2,
#  'prepared': 2,
#  'first week': 2,
#  'second week': 2,
#  'type: bug report': 2,
#  'bt-': 2,
#  'week-': 2,
#  '////internship/d/': 2,
#  'c: manager/widget': 2,
#  'new-package': 2,
#  'batch': 2,
#  'datacleaning': 2,
#  'ready for dev': 2,
#  's feedback': 2,
#  'area/test and release': 2,
#  'bug:confirmed': 2,
#  'browser-firefox-tablet': 2,
#  'install': 2,
#  'scrolling': 2,
#  'product owner': 2,
#  't: task': 2,
#  'feature-components': 2,
#  'technical': 2,
#  'kind/task': 2,
#  'workaround': 2,
#  'planning': 2,
#  't: feature': 2,
#  'severity/major': 2,
#  'kind/good-first-issue': 2,
#  '*duplicate': 2,
#  'valueerror': 2,
#  'decksite': 2,
#  'type.enhancement': 2,
#  'area: compiler': 2,
#  'aesthetic or design flaw': 2,
#  'beta.inyo.me': 2,
#  'needs testing': 2,
#  'area: code': 2,
#  'type: someting isnt working': 2,
#  'priority/': 2,
#  'doc': 2,
#  'code-actions': 2,
#  'questbook': 2,
#  'dataframe': 2,
#  'external': 2,
#  'false positive': 2,
#  'type: content :book:': 2,
#  'area/networking': 2,
#  'needs-more-info': 2,
#  't': 2,
#  '·resuelto·': 2,
#  'status: workaround available': 2,
#  'integrated-terminal': 2,
#  'migration': 2,
#  'location - server': 2,
#  'type - bug': 2,
#  'feature-testing': 2,
#  'authentication/subsvc': 2,
#  'js': 2,
#  'type: support': 2,
#  'développement': 2,
#  't-compiler': 2,
#  'waitingforinfo': 2,
#  'status: more info requested': 2,
#  'edit page': 2,
#  'pytanie': 2,
#  'area/doc': 2,
#  'rfc': 2,
#  'storage': 2,
#  'status: validated': 2,
#  'type: api': 2,
#  'related-server': 2,
#  'misc:dokany': 2,
#  'state:confirmed': 2,
#  'waiting_build': 2,
#  'waiting_verification': 2,
#  'version: x_stable': 2,
#  'melhoria': 2,
#  'status: pending pr': 2,
#  '- backlog': 2,
#  'ux controls': 2,
#  'sig/api-machinery': 2,
#  'status: assigned': 2,
#  'shelley': 2,
#  'type: help wanted': 2,
#  'area/deploy': 2,
#  'architecture': 2,
#  'grid': 2,
#  'type_feature': 2,
#  'video': 2,
#  'priority: p-high': 2,
#  ':bug: bug': 2,
#  'internal': 2,
#  'priority: normal': 2,
#  'comp:lite': 2,
#  'area: networking': 2,
#  'commons': 2,
#  'area - msbuild': 2,
#  'moss': 2,
#  'qa/retest': 2,
#  'to-be-closed': 2,
#  'web': 2,
#  't-infra': 2,
#  'type: feature request': 2,
#  'rest api': 2,
#  'metadata': 2,
#  'not enough info': 2,
#  'was:dropped': 2,
#  'dapp': 2,
#  'not reproducible': 2,
#  'platform: nrf': 2,
#  'funcion': 2,
#  'type.documentationbug': 2,
#  'release ..': 2,
#  'product/desktop-app': 2,
#  'feature enhancement': 2,
#  'size-m': 2,
#  'waiting for reply': 2,
#  'status: backlog': 2,
#  'status: committed': 2,
#  'product/runtime': 2,
#  'kobo': 2,
#  'diagram': 2,
#  'gruppa': 2,
#  'extensions': 2,
#  'breaking': 2,
#  'platform: linux': 2,
#  'highpriority': 2,
#  'caseflow-hearing-prep': 2,
#  'area/environments': 1,
#  'tiny': 1,
#  'blockage': 1,
#  'estimated': 1,
#  'feature-refactoring': 1,
#  'feature:search': 1,
#  'feature:telemetry': 1,
#  'a-c': 1,
#  'a-partitioning': 1,
#  'a-sql-syntax': 1,
#  'repl': 1,
#  'not-reproducible': 1,
#  'category: ux': 1,
#  'backtest': 1,
#  'severe: new feature': 1,
#  '○ platform-fuchsia': 1,
#  'back end': 1,
#  'waiting': 1,
#  'in:web services': 1,
#  'team:bobcats': 1,
#  'planned/in progress': 1,
#  'essential': 1,
#  'need testing': 1,
#  '🤔 question': 1,
#  'cat features missing': 1,
#  'flag doing': 1,
#  'frequency medium': 1,
#  'priority medium': 1,
#  'trouble medium': 1,
#  'type not implemented feature': 1,
#  'users member': 1,
#  'quick-fix': 1,
#  'microsoft submitter': 1,
#  'not-our-bug': 1,
#  'dqm-approved': 1,
#  'fully-signed': 1,
#  'application-gateway/svc': 1,
#  '\U0001f996 table block': 1,
#  'chess': 1,
#  'postgresql': 1,
#  'viz': 1,
#  'enhancements': 1,
#  'non-blocking': 1,
#  'plugins': 1,
#  'player': 1,
#  'port bug': 1,
#  'category: build/install': 1,
#  'question (invalid tracker)': 1,
#  'json protocol schema': 1,
#  'severity/minor': 1,
#  'type/ux': 1,
#  'coverity': 1,
#  'area: other': 1,
#  'all clients': 1,
#  'data-reg': 1,
#  'complexity/low': 1,
#  'area/monitoring': 1,
#  'fixed?': 1,
#  'needs refinestimation': 1,
#  'pipelines': 1,
#  'gitchecking/third-repo': 1,
#  'in-progress-queue': 1,
#  'inprogress-stale-hours--constraint': 1,
#  'low-priority': 1,
#  'testing-repo-group': 1,
#  '十分紧急': 1,
#  'feature specification': 1,
#  'in:transport': 1,
#  'team:sirius': 1,
#  'quality/release': 1,
#  'area/dashboard/templating': 1,
#  'front': 1,
#  'work: front-end': 1,
#  't - be enhancement': 1,
#  't - fe enhancement': 1,
#  'clt': 1,
#  'júnior': 1,
#  'pleno': 1,
#  'presencial': 1,
#  'inativa': 1,
#  'feat / lemmatizer': 1,
#  'docs: needed': 1,
#  'effort small': 1,
#  'area-engineering': 1,
#  'ybase': 1,
#  'component-wayback': 1,
#  'i - arcadia': 1,
#  'jib-core': 1,
#  'textfields': 1,
#  'type:process': 1,
#  'priority:med': 1,
#  'type: events': 1,
#  'type: outreach': 1,
#  'type: projects': 1,
#  'strings': 1,
#  'needs: reply': 1,
#  'bash': 1,
#  'codebusters': 1,
#  'bug / fix': 1,
#  'minizip': 1,
#  'cita': 1,
#  'other mod': 1,
#  'scope': 1,
#  'markdown extension': 1,
#  'infra': 1,
#  'rfe 🎁': 1,
#  'hwdb': 1,
#  'integration: esphome': 1,
#  'awaiting-more-evidence': 1,
#  'packaging/windowsmsi': 1,
#  'azure-government/svc': 1,
#  'us': 1,
#  'integration: zha': 1,
#  'user support': 1,
#  'a: in progress': 1,
#  'n: adguard for mac': 1,
#  'project management': 1,
#  'travel': 1,
#  'upstairs': 1,
#  'epic / fa removal feature': 1,
#  'a: tests': 1,
#  'connectivity': 1,
#  '. eletrônica': 1,
#  'needs-investigation': 1,
#  'overview': 1,
#  'app: rewards': 1,
#  'status: accepted': 1,
#  'status: pending': 1,
#  'type: feedback': 1,
#  'problem report': 1,
#  'area:pnp-powershell': 1,
#  'tcx_fixaccepted': 1,
#  'tcx_paid': 1,
#  'needs updates': 1,
#  'user testing': 1,
#  'engagement': 1,
#  'list subscriber activity report': 1,
#  'xs': 1,
#  'questions remain': 1,
#  'gitcoin grants': 1,
#  'revenue': 1,
#  'mdm': 1,
#  'more info or example needed': 1,
#  'policy settings': 1,
#  'admin side': 1,
#  'clients': 1,
#  'category: backend': 1,
#  'category: frontend': 1,
#  'priority: highest': 1,
#  'stage: in-progress': 1,
#  'p_low': 1,
#  't_document': 1,
#  'comment': 1,
#  'solution is not controversial': 1,
#  'up for grabs': 1,
#  'file icons': 1,
#  'narrative': 1,
#  'moving': 1,
#  'provider/azurerm': 1,
#  'sbt-plugin': 1,
#  'vcs': 1,
#  'domain: jsdoc': 1,
#  'vs code priority': 1,
#  'waiting reply': 1,
#  'xsdk-.-release': 1,
#  'firebase': 1,
#  'firebase_remote_config': 1,
#  'first party': 1,
#  'financial': 1,
#  'bug leve': 1,
#  'fontend': 1,
#  'impact low': 1,
#  'likelihood medium': 1,
#  'needs_verified': 1,
#  'status needs author reply': 1,
#  'known bug': 1,
#  'nightscout': 1,
#  'area-ide': 1,
#  'urgency-now': 1,
#  'placeholder': 1,
#  'price list': 1,
#  'nice to have': 1,
#  'bounty-xs': 1,
#  'effor: hours': 1,
#  'internal contributor': 1,
#  'ci': 1,
#  'feature:dependency injection': 1,
#  'area/airflow': 1,
#  'area/orbit-ui': 1,
#  'size/l': 1,
#  'done!': 1,
#  'zube: in progress': 1,
#  'os-mac-os-x': 1,
#  'beginner pro': 1,
#  'revc': 1,
#  'actualizaciones fork': 1,
#  'format cii': 1,
#  'random': 1,
#  'd': 1,
#  '已解决待确认': 1,
#  '需求': 1,
#  'algorithm': 1,
#  'user land': 1,
#  'label': 1,
#  'another label': 1,
#  'easy issue': 1,
#  'communities': 1,
#  'cannon': 1,
#  'three': 1,
#  'area: excel': 1,
#  'verified/in progress': 1,
#  'nethcti': 1,
#  'client waiting...': 1,
#  'rc_z_--': 1,
#  '⚡ heads up ⚡': 1,
#  'has fix': 1,
#  'logic': 1,
#  'styling': 1,
#  'type: design': 1,
#  'rpm': 1,
#  'hard': 1,
#  'i refuse': 1,
#  'wont do': 1,
#  'delay-until-inspiration': 1,
#  'branch:master': 1,
#  'branch:release': 1,
#  'exp/beginner': 1,
#  'type: ay ♿': 1,
#  'shiproom-review': 1,
#  'compliance-assesment': 1,
#  'next up': 1,
#  'asset': 1,
#  'cgo': 1,
#  'go': 1,
#  'cli': 1,
#  'accepting prs': 1,
#  'dx': 1,
#  'effort: easy': 1,
#  'kr': 1,
#  'v.kr-desktop-..': 1,
#  'c-tracking-issue': 1,
#  'bug (critical)': 1,
#  'cat/build': 1,
#  'comp:gpu': 1,
#  'optimsoc': 1,
#  'effort: few hours': 1,
#  'status: in-progress': 1,
#  't: bugreport': 1,
#  'cant replicate': 1,
#  'impact-breaks-consumers': 1,
#  'impact-breaks-producers': 1,
#  'resolved-fixed': 1,
#  'prio: normal': 1,
#  'needs: help': 1,
#  'lvl: easy': 1,
#  'tag: ux accessibility': 1,
#  'nightmode': 1,
#  'component: config': 1,
#  'issue: confirmed': 1,
#  'issue: ready for work': 1,
#  'reproduced on ..x': 1,
#  '- low priority': 1,
#  'project_cancelled': 1,
#  'intermediate': 1,
#  't-shirt large': 1,
#  'sonar cloud': 1,
#  'status:discussion': 1,
#  'talk': 1,
#  'comp:jit': 1,
#  'comp:jit:z': 1,
#  '问题': 1,
#  'data needed': 1,
#  'parser': 1,
#  'research library 📚': 1,
#  'code-quality': 1,
#  '.deferred_dev': 1,
#  'new method': 1,
#  't-shirt small': 1,
#  'type-perf': 1,
#  'in flutter': 1,
#  'is enhancement': 1,
#  'on chromeos': 1,
#  'search & browse': 1,
#  ...}

# %%
freq['bug']+=freq.pop('type: bug')
freq['bug']+=freq.pop('kind/bug')
freq['bug']+=freq.pop('type_bug')
freq['bug']+=freq.pop('type:bug')
freq['bug']+=freq.pop('type bug')
freq['bug']+=freq.pop('type.bug')
freq['bug']+=freq.pop('type-bug')
freq['enhancement']+=freq.pop('type: enhancement')
freq['enhancement']+=freq.pop('type:enhancement')
freq['enhancement']+=freq.pop('kind/enhancement')
freq['feature']+=freq.pop('feature request')
freq['feature']+=freq.pop('new feature')
freq['feature']+=freq.pop('type: feature')
freq['documentation']+=freq.pop('docs')
freq['high priority']+=freq.pop('priority: high')
freq['high priority']+=freq.pop('priority - high')
freq['high priority']+=freq.pop('priority/high')
freq['high priority']+=freq.pop('priority.high')
freq['priority: medium']+=freq.pop('priority.medium')
freq['priority: medium']+=freq.pop('medium priority')
freq['question']+=freq.pop('type: question')
freq['question']+=freq.pop('kind/question')
freq['enhancement']+=freq.pop('improvement')
freq['support']+=freq.pop('type:support')
freq['in progress']+=freq.pop('in-progress')
freq['good first issue']+=freq.pop('good-first-issue')

# %%
freq
# Out:
# {'bug': 841,
#  'enhancement': 646,
#  'question': 173,
#  'help wanted': 106,
#  'good first issue': 93,
#  'feature': 122,
#  'wontfix': 75,
#  'stale': 50,
#  'p': 48,
#  'greenkeeper': 47,
#  'in progress': 51,
#  'triaged': 42,
#  'documentation': 63,
#  'task': 36,
#  'medium': 36,
#  'duplicate': 35,
#  'invalid': 30,
#  'user-submission': 25,
#  'high priority': 64,
#  'ui': 23,
#  'assigned-to-author': 23,
#  'priority: medium': 39,
#  'review': 21,
#  '': 21,
#  'design': 19,
#  'high': 19,
#  'n: adguard browser extension': 18,
#  'frontend': 18,
#  'epic': 18,
#  'support': 26,
#  'fixed': 17,
#  'browser-firefox': 17,
#  'backend': 15,
#  'priority/p': 15,
#  'new-version': 14,
#  'cxp': 14,
#  'triage': 14,
#  'critical': 14,
#  'browser-firefox-mobile': 14,
#  'discussion': 13,
#  'sprint': 13,
#  'version/.': 13,
#  '.': 13,
#  'doc-enhancement': 12,
#  'approved': 12,
#  'eps': 11,
#  'in scope (june )': 11,
#  'backlog': 11,
#  'target/..': 11,
#  'lang/zh': 11,
#  'priority: low': 11,
#  'resolved': 11,
#  'kind/feature': 11,
#  'todo': 11,
#  'a: resolved': 11,
#  'gitalk': 11,
#  'ver: ..': 11,
#  'low': 10,
#  'front end': 10,
#  'doc-bug': 10,
#  'scan:--': 10,
#  'a: cannot reproduce': 10,
#  't: annoyance': 10,
#  'api': 10,
#  'needs more info': 10,
#  'security vulnerability': 10,
#  'product-question': 10,
#  'ios': 9,
#  't: anti adblock script': 9,
#  'sync/new': 9,
#  'nsfw': 9,
#  'new-review': 9,
#  'v..': 9,
#  'priority': 9,
#  'windows': 9,
#  'mvp': 9,
#  'ui/ux': 9,
#  'priority-critical': 9,
#  'proposal': 9,
#  'user story': 8,
#  'needs pr': 8,
#  'low priority': 8,
#  'easy': 8,
#  'type: bug 🐛': 8,
#  'urgent': 8,
#  'n: adguard for windows': 8,
#  'blocked': 8,
#  'android': 8,
#  'blocker': 8,
#  'framework': 8,
#  'priority-normal': 8,
#  'inactive': 8,
#  't: ads': 8,
#  'ships-in-future-update': 8,
#  'investigate': 8,
#  'accepted': 8,
#  'project: website': 8,
#  '🐞 bug': 8,
#  'client': 7,
#  'fixed in dev': 7,
#  'build': 7,
#  't: incorrect blocking': 7,
#  'ux': 7,
#  'gssoc': 7,
#  'ready': 7,
#  'priority: critical': 7,
#  'testing': 7,
#  'type: dev :robot:': 7,
#  'regression': 7,
#  'priority-important': 7,
#  'priority: p': 7,
#  'to do': 7,
#  'normal': 7,
#  'project': 7,
#  'auto-migrated': 7,
#  'sf-archive': 7,
#  'devops': 6,
#  'spike': 6,
#  'area-mvc': 6,
#  'ready for retest': 6,
#  'past--days': 6,
#  'lifecycle/rotten': 6,
#  'affects_.': 6,
#  'q': 6,
#  'severity.medium': 6,
#  'in review': 6,
#  'type: regression': 6,
#  'pending': 6,
#  'security': 6,
#  'core': 6,
#  '..': 6,
#  'topic:core': 6,
#  'performance': 6,
#  'front-end': 6,
#  'active-directory/svc': 6,
#  'mds': 6,
#  'type: refactor': 5,
#  'suggestion': 5,
#  'production': 5,
#  'type.story': 5,
#  'usability': 5,
#  'current sprint': 5,
#  'validation': 5,
#  'back-end': 5,
#  'stale?': 5,
#  'fixed confirmed': 5,
#  'stat:awaiting response': 5,
#  'type:bug/performance': 5,
#  'needs investigation': 5,
#  'python': 5,
#  'major': 5,
#  'th': 5,
#  'priority-': 5,
#  'refactoring': 5,
#  'request-for-external': 5,
#  'javascript': 5,
#  'lifecycle/stale': 5,
#  'crash': 5,
#  'refactor': 5,
#  't: bug': 5,
#  'confirmed': 5,
#  'tango': 5,
#  'upstream': 5,
#  'v.x': 5,
#  'c-bug': 5,
#  'has pr': 5,
#  'needs-repro': 4,
#  'c-enhancement': 4,
#  'tests': 4,
#  'error:crash': 4,
#  'easy fix': 4,
#  'breaking change': 4,
#  'important': 4,
#  'type/bug': 4,
#  'component': 4,
#  'content': 4,
#  'v.': 4,
#  'release bug': 4,
#  'homework': 4,
#  'css': 4,
#  'infrastructure': 4,
#  'status: resolved': 4,
#  '. needs triage': 4,
#  'programming': 4,
#  'sig/scheduling': 4,
#  'severe: crash': 4,
#  'ops': 4,
#  'bounty': 4,
#  'minor': 4,
#  'area-system.net.http.socketshttphandler': 4,
#  'type: documentation': 4,
#  'n: adguard for ios': 4,
#  'major city': 4,
#  'tide/merge-blocker': 4,
#  'bug :bug:': 4,
#  'component/ui': 4,
#  'comp:ops': 4,
#  'f: material design': 4,
#  'area/ci': 4,
#  'area/cli': 4,
#  'data': 4,
#  'defect': 4,
#  'arendus: back-end': 4,
#  'needs info': 4,
#  'type: maintenance': 4,
#  'v': 4,
#  'category: core': 4,
#  'doc feedback': 4,
#  'topic:editor': 4,
#  'need more info': 4,
#  'status/resolved': 4,
#  'status/triaged': 4,
#  'reporting': 4,
#  'bug :beetle:': 4,
#  '...': 4,
#  'done': 4,
#  'team': 4,
#  'need approval': 4,
#  'version ..': 4,
#  'status/ready-for-review': 4,
#  'type:feature': 4,
#  'week': 4,
#  'brak_odpowiedzi': 4,
#  'type-code health': 3,
#  'priority:low': 3,
#  'priority:high': 3,
#  'training': 3,
#  'state_verification': 3,
#  'app: projects': 3,
#  '🐛 bug': 3,
#  'server': 3,
#  'service bus': 3,
#  'large': 3,
#  'status: in progress': 3,
#  'code': 3,
#  'packaging': 3,
#  'type.task': 3,
#  '- in review': 3,
#  'waiting for feedback': 3,
#  'needs review': 3,
#  'community': 3,
#  'tech debt': 3,
#  'linux': 3,
#  'welcome': 3,
#  'investigating': 3,
#  'plugin': 3,
#  'branding': 3,
#  'patch': 3,
#  'yaml content request': 3,
#  'script': 3,
#  'art': 3,
#  'gas': 3,
#  'support:core': 3,
#  'type: docs': 3,
#  'type-enhancement': 3,
#  'priority/important': 3,
#  '- ready': 3,
#  'priority - medium': 3,
#  'repo settings': 3,
#  'document': 3,
#  'sprint day': 3,
#  'data import': 3,
#  'merged': 3,
#  'development': 3,
#  'scheduled': 3,
#  'type: spec': 3,
#  'product feedback': 3,
#  'committed': 3,
#  'demo': 3,
#  'event-request': 3,
#  'os:windows': 3,
#  'fixed in next update': 3,
#  'status: available': 3,
#  'low hanging fruit': 3,
#  'i: needs triage': 3,
#  'bug bash': 3,
#  'sf': 3,
#  'area-codegen': 3,
#  'tier': 3,
#  'pinned': 3,
#  'compatibility': 3,
#  'tarea': 3,
#  'requirements ready': 3,
#  'state dept.': 3,
#  't: defect': 3,
#  'source - docs.ms': 3,
#  'status.ongoing': 3,
#  'p-': 3,
#  'new release': 3,
#  'type - bug report': 3,
#  'sig/storage': 3,
#  'tenet-compatibility': 3,
#  'needs discussion': 3,
#  'type: bug :bug:': 3,
#  'mobile': 3,
#  'database': 3,
#  '-- :: + cst': 3,
#  'icebox': 3,
#  'macos': 3,
#  ':beetle: bug :beetle:': 3,
#  'nes': 3,
#  'pulsetile-ra': 3,
#  'state: fixed': 3,
#  'test': 3,
#  'area/ui': 3,
#  'more-info-required': 3,
#  'admin': 3,
#  'status/to-test': 3,
#  'team/ca': 3,
#  'pf website issue': 3,
#  'compliment': 3,
#  'type: enhancement ✨': 3,
#  'meta': 3,
#  'backend:tensorflow': 3,
#  'feature-request': 3,
#  'status: waiting-for-reply': 3,
#  'difficulty: medium': 3,
#  'topic:gdscript': 3,
#  '*caused-by-extension': 3,
#  'solved': 3,
#  'zube: in review': 3,
#  'next release': 3,
#  't: enhancement': 3,
#  'to be closed': 3,
#  'caseflow-hearing-schedule': 3,
#  'browser-focus-geckoview': 3,
#  'kind/test failure': 3,
#  'sp:': 3,
#  'feat': 3,
#  'kind/bug-qa': 3,
#  '.-stable': 3,
#  'model': 3,
#  '- task': 3,
#  'group': 3,
#  'storage/svc': 3,
#  'size:s': 3,
#  'dependency': 3,
#  'translation': 3,
#  'ci/cd': 3,
#  'future build': 3,
#  'type: question or discussion': 3,
#  'more info needed': 3,
#  'tech-improvement-backlog': 3,
#  'v :new:': 3,
#  'docker': 3,
#  'editorial': 3,
#  'calibration request': 3,
#  'site-recovery/svc': 3,
#  'arch-arm': 3,
#  'apitestuat': 2,
#  'compiler': 2,
#  'backport': 2,
#  'tool': 2,
#  'cgmes': 2,
#  'prio:high': 2,
#  'area-servers': 2,
#  'customer': 2,
#  'chore': 2,
#  'view': 2,
#  'профильподготовки': 2,
#  'engine': 2,
#  'documentação': 2,
#  'po': 2,
#  'issue': 2,
#  'optimization': 2,
#  'bug report': 2,
#  'editor': 2,
#  'unity': 2,
#  'client management': 2,
#  'size': 2,
#  'component: core': 2,
#  'smart contracts': 2,
#  'more-info-needed': 2,
#  'shop': 2,
#  'needsfix': 2,
#  'area/replication': 2,
#  'sync/update': 2,
#  'gemensam': 2,
#  'needs-priority': 2,
#  'difficulty:moderate': 2,
#  'service-fabric/svc': 2,
#  'type: improvement': 2,
#  'management': 2,
#  'audio': 2,
#  'intellij': 2,
#  'logistics': 2,
#  'improvements': 2,
#  'tengo un error': 2,
#  'debug': 2,
#  'html/css': 2,
#  'prioritary': 2,
#  '功能实现': 2,
#  'answered': 2,
#  'implemented': 2,
#  'react': 2,
#  'unscheduled': 2,
#  'data science': 2,
#  'beginner': 2,
#  'new api': 2,
#  ':infrastructure': 2,
#  'metricbeat': 2,
#  'liveshare': 2,
#  '用户测试': 2,
#  'db': 2,
#  'fix pending': 2,
#  'verified': 2,
#  'type:documentation': 2,
#  'project: components': 2,
#  'source issue': 2,
#  'priority/low': 2,
#  'a-impl-trait': 2,
#  'status stale': 2,
#  'status/stale': 2,
#  'important and urgent': 2,
#  'hashmap': 2,
#  'type: new feature': 2,
#  'csd.': 2,
#  'type: system': 2,
#  'asana': 2,
#  'issue: format is valid': 2,
#  'pr submitted': 2,
#  'in': 2,
#  'feature-*': 2,
#  'pr open': 2,
#  'need feedback': 2,
#  'status: in review': 2,
#  'needs-info': 2,
#  'status: ready for release': 2,
#  'r.-dom-cur-test': 2,
#  'gv': 2,
#  'priority/medium': 2,
#  'component: table': 2,
#  'severity: medium': 2,
#  'version: ..x': 2,
#  '..-alpha': 2,
#  'developed': 2,
#  'c++': 2,
#  'auto': 2,
#  'gui': 2,
#  'i: bug': 2,
#  'architect': 2,
#  'type: help wanted 🤷\u200d♂️': 2,
#  'network': 2,
#  'd-lite': 2,
#  'keyboard': 2,
#  'visualization': 2,
#  'more information needed': 2,
#  'dev': 2,
#  'cat/enhancement': 2,
#  'notif/triage': 2,
#  'subj: ui/ux': 2,
#  'feature/rewards': 2,
#  'high-priority': 2,
#  'c: code generation': 2,
#  'e: all editions': 2,
#  'r: fixed': 2,
#  ':watch: not triaged': 2,
#  'semantic-release': 2,
#  'analytics': 2,
#  'pending-close-response-required': 2,
#  'breaking-change': 2,
#  'type: process': 2,
#  'needs repro': 2,
#  'change': 2,
#  'hasfix': 2,
#  'pr - ready to be committed': 2,
#  'status - has pull request': 2,
#  't - enhancement': 2,
#  'area-compilers': 2,
#  'new language feature - nullable reference types': 2,
#  '\U0001f9ea testing': 2,
#  'interface': 2,
#  'for: up for grabs': 2,
#  'arendus: front-end': 2,
#  'c-test-failure': 2,
#  'o-robot': 2,
#  'area/auth-integration': 2,
#  'triple integration 🔱': 2,
#  'incomplete': 2,
#  'type: not bug': 2,
#  'p-medium': 2,
#  'status: needs triage': 2,
#  'sprint one': 2,
#  'backport .': 2,
#  'bot': 2,
#  'low effort': 2,
#  'fix proposed': 2,
#  'resolved: next release': 2,
#  '-april': 2,
#  'fc-redirect-technical': 2,
#  'waiting for review': 2,
#  'io': 2,
#  ':grey_exclamation: priority low': 2,
#  'priority-high': 2,
#  'status: defined': 2,
#  'status: wontfix': 2,
#  'area - code analysis': 2,
#  'mac': 2,
#  'type: security': 2,
#  'bugbash': 2,
#  'issue-discussion': 2,
#  'vsts': 2,
#  'data-factory/svc': 2,
#  'backtrace.io': 2,
#  ':books: area - c# guide': 2,
#  'qa/pass': 2,
#  'product-issue': 2,
#  't - feature': 2,
#  'helpdesk': 2,
#  'source: offline chat': 2,
#  'rc.': 2,
#  'bug/-confirmed': 2,
#  'user experience': 2,
#  'could close': 2,
#  'status: review needed': 2,
#  '>bug': 2,
#  'priority:medium': 2,
#  'type:project-task': 2,
#  'orange': 2,
#  'wip': 2,
#  'c/cli': 2,
#  'story': 2,
#  'cleanup': 2,
#  'm-low': 2,
#  'epic historie- en versiebeheer (sprint )': 2,
#  'prio h': 2,
#  'component:arc': 2,
#  'auth': 2,
#  'stat:awaiting tensorflower': 2,
#  'typing': 2,
#  '--x': 2,
#  'typescript': 2,
#  'construction': 2,
#  'support request': 2,
#  'version/..': 2,
#  'helm': 2,
#  'todo :spiral_notepad:': 2,
#  'severity.low': 2,
#  'new': 2,
#  'ep request': 2,
#  'status: abandoned': 2,
#  'platform: ios': 2,
#  'type: accepted/bug': 2,
#  'area:usecases': 2,
#  'state_inprogress': 2,
#  'wanted': 2,
#  'no triage': 2,
#  'doublechecked': 2,
#  'bo': 2,
#  'type enhancement': 2,
#  'f-enhancement 🎁': 2,
#  'pri: - required': 2,
#  'orion reviewed': 2,
#  'layout': 2,
#  'area: artifacts': 2,
#  'http': 2,
#  'pf': 2,
#  'inbox': 2,
#  'user': 2,
#  'period/.': 2,
#  'type: issue': 2,
#  'c: core': 2,
#  'kind/documentation': 2,
#  'prepared': 2,
#  'first week': 2,
#  'second week': 2,
#  'type: bug report': 2,
#  'bt-': 2,
#  'week-': 2,
#  '////internship/d/': 2,
#  'c: manager/widget': 2,
#  'new-package': 2,
#  'batch': 2,
#  'datacleaning': 2,
#  'ready for dev': 2,
#  's feedback': 2,
#  'area/test and release': 2,
#  'bug:confirmed': 2,
#  'browser-firefox-tablet': 2,
#  'install': 2,
#  'scrolling': 2,
#  'product owner': 2,
#  't: task': 2,
#  'feature-components': 2,
#  'technical': 2,
#  'kind/task': 2,
#  'workaround': 2,
#  'planning': 2,
#  't: feature': 2,
#  'severity/major': 2,
#  'kind/good-first-issue': 2,
#  '*duplicate': 2,
#  'valueerror': 2,
#  'decksite': 2,
#  'type.enhancement': 2,
#  'area: compiler': 2,
#  'aesthetic or design flaw': 2,
#  'beta.inyo.me': 2,
#  'needs testing': 2,
#  'area: code': 2,
#  'type: someting isnt working': 2,
#  'priority/': 2,
#  'doc': 2,
#  'code-actions': 2,
#  'questbook': 2,
#  'dataframe': 2,
#  'external': 2,
#  'false positive': 2,
#  'type: content :book:': 2,
#  'area/networking': 2,
#  'needs-more-info': 2,
#  't': 2,
#  '·resuelto·': 2,
#  'status: workaround available': 2,
#  'integrated-terminal': 2,
#  'migration': 2,
#  'location - server': 2,
#  'type - bug': 2,
#  'feature-testing': 2,
#  'authentication/subsvc': 2,
#  'js': 2,
#  'type: support': 2,
#  'développement': 2,
#  't-compiler': 2,
#  'waitingforinfo': 2,
#  'status: more info requested': 2,
#  'edit page': 2,
#  'pytanie': 2,
#  'area/doc': 2,
#  'rfc': 2,
#  'storage': 2,
#  'status: validated': 2,
#  'type: api': 2,
#  'related-server': 2,
#  'misc:dokany': 2,
#  'state:confirmed': 2,
#  'waiting_build': 2,
#  'waiting_verification': 2,
#  'version: x_stable': 2,
#  'melhoria': 2,
#  'status: pending pr': 2,
#  '- backlog': 2,
#  'ux controls': 2,
#  'sig/api-machinery': 2,
#  'status: assigned': 2,
#  'shelley': 2,
#  'type: help wanted': 2,
#  'area/deploy': 2,
#  'architecture': 2,
#  'grid': 2,
#  'type_feature': 2,
#  'video': 2,
#  'priority: p-high': 2,
#  ':bug: bug': 2,
#  'internal': 2,
#  'priority: normal': 2,
#  'comp:lite': 2,
#  'area: networking': 2,
#  'commons': 2,
#  'area - msbuild': 2,
#  'moss': 2,
#  'qa/retest': 2,
#  'to-be-closed': 2,
#  'web': 2,
#  't-infra': 2,
#  'type: feature request': 2,
#  'rest api': 2,
#  'metadata': 2,
#  'not enough info': 2,
#  'was:dropped': 2,
#  'dapp': 2,
#  'not reproducible': 2,
#  'platform: nrf': 2,
#  'funcion': 2,
#  'type.documentationbug': 2,
#  'release ..': 2,
#  'product/desktop-app': 2,
#  'feature enhancement': 2,
#  'size-m': 2,
#  'waiting for reply': 2,
#  'status: backlog': 2,
#  'status: committed': 2,
#  'product/runtime': 2,
#  'kobo': 2,
#  'diagram': 2,
#  'gruppa': 2,
#  'extensions': 2,
#  'breaking': 2,
#  'platform: linux': 2,
#  'highpriority': 2,
#  'caseflow-hearing-prep': 2,
#  'area/environments': 1,
#  'tiny': 1,
#  'blockage': 1,
#  'estimated': 1,
#  'feature-refactoring': 1,
#  'feature:search': 1,
#  'feature:telemetry': 1,
#  'a-c': 1,
#  'a-partitioning': 1,
#  'a-sql-syntax': 1,
#  'repl': 1,
#  'not-reproducible': 1,
#  'category: ux': 1,
#  'backtest': 1,
#  'severe: new feature': 1,
#  '○ platform-fuchsia': 1,
#  'back end': 1,
#  'waiting': 1,
#  'in:web services': 1,
#  'team:bobcats': 1,
#  'planned/in progress': 1,
#  'essential': 1,
#  'need testing': 1,
#  '🤔 question': 1,
#  'cat features missing': 1,
#  'flag doing': 1,
#  'frequency medium': 1,
#  'priority medium': 1,
#  'trouble medium': 1,
#  'type not implemented feature': 1,
#  'users member': 1,
#  'quick-fix': 1,
#  'microsoft submitter': 1,
#  'not-our-bug': 1,
#  'dqm-approved': 1,
#  'fully-signed': 1,
#  'application-gateway/svc': 1,
#  '\U0001f996 table block': 1,
#  'chess': 1,
#  'postgresql': 1,
#  'viz': 1,
#  'enhancements': 1,
#  'non-blocking': 1,
#  'plugins': 1,
#  'player': 1,
#  'port bug': 1,
#  'category: build/install': 1,
#  'question (invalid tracker)': 1,
#  'json protocol schema': 1,
#  'severity/minor': 1,
#  'type/ux': 1,
#  'coverity': 1,
#  'area: other': 1,
#  'all clients': 1,
#  'data-reg': 1,
#  'complexity/low': 1,
#  'area/monitoring': 1,
#  'fixed?': 1,
#  'needs refinestimation': 1,
#  'pipelines': 1,
#  'gitchecking/third-repo': 1,
#  'in-progress-queue': 1,
#  'inprogress-stale-hours--constraint': 1,
#  'low-priority': 1,
#  'testing-repo-group': 1,
#  '十分紧急': 1,
#  'feature specification': 1,
#  'in:transport': 1,
#  'team:sirius': 1,
#  'quality/release': 1,
#  'area/dashboard/templating': 1,
#  'front': 1,
#  'work: front-end': 1,
#  't - be enhancement': 1,
#  't - fe enhancement': 1,
#  'clt': 1,
#  'júnior': 1,
#  'pleno': 1,
#  'presencial': 1,
#  'inativa': 1,
#  'feat / lemmatizer': 1,
#  'docs: needed': 1,
#  'effort small': 1,
#  'area-engineering': 1,
#  'ybase': 1,
#  'component-wayback': 1,
#  'i - arcadia': 1,
#  'jib-core': 1,
#  'textfields': 1,
#  'type:process': 1,
#  'priority:med': 1,
#  'type: events': 1,
#  'type: outreach': 1,
#  'type: projects': 1,
#  'strings': 1,
#  'needs: reply': 1,
#  'bash': 1,
#  'codebusters': 1,
#  'bug / fix': 1,
#  'minizip': 1,
#  'cita': 1,
#  'other mod': 1,
#  'scope': 1,
#  'markdown extension': 1,
#  'infra': 1,
#  'rfe 🎁': 1,
#  'hwdb': 1,
#  'integration: esphome': 1,
#  'awaiting-more-evidence': 1,
#  'packaging/windowsmsi': 1,
#  'azure-government/svc': 1,
#  'us': 1,
#  'integration: zha': 1,
#  'user support': 1,
#  'a: in progress': 1,
#  'n: adguard for mac': 1,
#  'project management': 1,
#  'travel': 1,
#  'upstairs': 1,
#  'epic / fa removal feature': 1,
#  'a: tests': 1,
#  'connectivity': 1,
#  '. eletrônica': 1,
#  'needs-investigation': 1,
#  'overview': 1,
#  'app: rewards': 1,
#  'status: accepted': 1,
#  'status: pending': 1,
#  'type: feedback': 1,
#  'problem report': 1,
#  'area:pnp-powershell': 1,
#  'tcx_fixaccepted': 1,
#  'tcx_paid': 1,
#  'needs updates': 1,
#  'user testing': 1,
#  'engagement': 1,
#  'list subscriber activity report': 1,
#  'xs': 1,
#  'questions remain': 1,
#  'gitcoin grants': 1,
#  'revenue': 1,
#  'mdm': 1,
#  'more info or example needed': 1,
#  'policy settings': 1,
#  'admin side': 1,
#  'clients': 1,
#  'category: backend': 1,
#  'category: frontend': 1,
#  'priority: highest': 1,
#  'stage: in-progress': 1,
#  'p_low': 1,
#  't_document': 1,
#  'comment': 1,
#  'solution is not controversial': 1,
#  'up for grabs': 1,
#  'file icons': 1,
#  'narrative': 1,
#  'moving': 1,
#  'provider/azurerm': 1,
#  'sbt-plugin': 1,
#  'vcs': 1,
#  'domain: jsdoc': 1,
#  'vs code priority': 1,
#  'waiting reply': 1,
#  'xsdk-.-release': 1,
#  'firebase': 1,
#  'firebase_remote_config': 1,
#  'first party': 1,
#  'financial': 1,
#  'bug leve': 1,
#  'fontend': 1,
#  'impact low': 1,
#  'likelihood medium': 1,
#  'needs_verified': 1,
#  'status needs author reply': 1,
#  'known bug': 1,
#  'nightscout': 1,
#  'area-ide': 1,
#  'urgency-now': 1,
#  'placeholder': 1,
#  'price list': 1,
#  'nice to have': 1,
#  'bounty-xs': 1,
#  'effor: hours': 1,
#  'internal contributor': 1,
#  'ci': 1,
#  'feature:dependency injection': 1,
#  'area/airflow': 1,
#  'area/orbit-ui': 1,
#  'size/l': 1,
#  'done!': 1,
#  'zube: in progress': 1,
#  'os-mac-os-x': 1,
#  'beginner pro': 1,
#  'revc': 1,
#  'actualizaciones fork': 1,
#  'format cii': 1,
#  'random': 1,
#  'd': 1,
#  '已解决待确认': 1,
#  '需求': 1,
#  'algorithm': 1,
#  'user land': 1,
#  'label': 1,
#  'another label': 1,
#  'easy issue': 1,
#  'communities': 1,
#  'cannon': 1,
#  'three': 1,
#  'area: excel': 1,
#  'verified/in progress': 1,
#  'nethcti': 1,
#  'client waiting...': 1,
#  'rc_z_--': 1,
#  '⚡ heads up ⚡': 1,
#  'has fix': 1,
#  'logic': 1,
#  'styling': 1,
#  'type: design': 1,
#  'rpm': 1,
#  'hard': 1,
#  'i refuse': 1,
#  'wont do': 1,
#  'delay-until-inspiration': 1,
#  'branch:master': 1,
#  'branch:release': 1,
#  'exp/beginner': 1,
#  'type: ay ♿': 1,
#  'shiproom-review': 1,
#  'compliance-assesment': 1,
#  'next up': 1,
#  'asset': 1,
#  'cgo': 1,
#  'go': 1,
#  'cli': 1,
#  'accepting prs': 1,
#  'dx': 1,
#  'effort: easy': 1,
#  'kr': 1,
#  'v.kr-desktop-..': 1,
#  'c-tracking-issue': 1,
#  'bug (critical)': 1,
#  'cat/build': 1,
#  'comp:gpu': 1,
#  'optimsoc': 1,
#  'effort: few hours': 1,
#  'status: in-progress': 1,
#  't: bugreport': 1,
#  'cant replicate': 1,
#  'impact-breaks-consumers': 1,
#  'impact-breaks-producers': 1,
#  'resolved-fixed': 1,
#  'prio: normal': 1,
#  'needs: help': 1,
#  'lvl: easy': 1,
#  'tag: ux accessibility': 1,
#  'nightmode': 1,
#  'component: config': 1,
#  'issue: confirmed': 1,
#  'issue: ready for work': 1,
#  'reproduced on ..x': 1,
#  '- low priority': 1,
#  'project_cancelled': 1,
#  'intermediate': 1,
#  't-shirt large': 1,
#  'sonar cloud': 1,
#  'status:discussion': 1,
#  'talk': 1,
#  'comp:jit': 1,
#  'comp:jit:z': 1,
#  '问题': 1,
#  'data needed': 1,
#  'parser': 1,
#  'research library 📚': 1,
#  'code-quality': 1,
#  '.deferred_dev': 1,
#  'new method': 1,
#  't-shirt small': 1,
#  'type-perf': 1,
#  'in flutter': 1,
#  'is enhancement': 1,
#  'on chromeos': 1,
#  'search & browse': 1,
#  'sistina': 1,
#  'component: gui': 1,
#  'client reported': 1,
#  'storybook': 1,
#  'feature:aggregations': 1,
#  'feature:message-editing': 1,
#  'feature:reactions': 1,
#  'hub': 1,
#  'subtype:image retraining': 1,
#  'skin-duke-default': 1,
#  'gruppb': 1,
#  'area/sdk': 1,
#  'mssql': 1,
#  'indispensable': 1,
#  'revue ux & design': 1,
#  'from: consumer': 1,
#  'component: ghcjs': 1,
#  'type: discuss': 1,
#  'patric': 1,
#  'service: others': 1,
#  'api: firestore': 1,
#  'for: design': 1,
#  'reject': 1,
#  't - bug': 1,
#  'component/backend': 1,
#  'sev/new_feature': 1,
#  ...}

# %%
len(freq)
# Out:
# 2741

# %%
labeled['try'][:150]
# Out:
# 0                                            needs-repro
# 1                                            enhancement
# 4                                      area/environments
# 5      user story,bug,high priority,tiny,blockage,est...
# 6      feature-refactoring,good first issue,needs pr,...
# 7                                                feature
# 8                 feature:search,feature:telemetry,p,a-c
# 9              a-partitioning,a-sql-syntax,c-enhancement
# 12                              enhancement,priority:low
# 13                                            apitestuat
# 14                                           enhancement
# 15                       bug,compiler,priority:high,repl
# 23                                      not-reproducible
# 24                                               support
# 25                                  backport,enhancement
# 26                                      category: ux,low
# 31                             backtest,good first issue
# 32           severe: new feature,tool,○ platform-fuchsia
# 34                                             cgmes,bug
# 35                                           enhancement
# 39                         priority: high,type: refactor
# 40                                                   bug
# 43                      back end,feature,priority - high
# 44                                              question
# 45                                               wontfix
# 46                                           enhancement
# 47                                                   bug
# 48                                                   bug
# 49                     feature,front end,priority - high
# 50                                              training
# 51                                         bug,prio:high
# 52                                  area-servers,waiting
# 53                                           enhancement
# 55                          in:web services,team:bobcats
# 58                        planned/in progress,suggestion
# 61                                 essential,enhancement
# 63                                                   bug
# 66                           state_verification,type_bug
# 67                                          bug,customer
# 71                          need testing,bug,enhancement
# 72                                                bug,ui
# 74                                                   bug
# 76                                                 tests
# 77                                            🤔 question
# 79                                                   bug
# 80                                                 chore
# 82                                                   bug
# 85                               low priority,suggestion
# 87     cat features missing,flag doing,frequency medi...
# 88                                                 p,bug
# 89                               app: projects,quick-fix
# 91                                   microsoft submitter
# 92                                           not-our-bug
# 94                                                   bug
# 97                                                   bug
# 98                             dqm-approved,fully-signed
# 101    application-gateway/svc,assigned-to-author,doc...
# 105                                                  bug
# 106                                  🐛 bug,🦖 table block
# 107                                            bug,chess
# 108                                     devops,eps,spike
# 109    error:crash,production,scan:--,scan:--,scan:--...
# 115                           bug,view,профильподготовки
# 116                           engine,postgresql,question
# 117                                                  viz
# 119                                         documentação
# 124           easy fix,enhancements,non-blocking,plugins
# 127                                                  bug
# 128                                  breaking change,bug
# 129                                          new feature
# 132                                               eps,po
# 135                                             question
# 139                                        player,server
# 140                                   client,service bus
# 143                                            duplicate
# 144                                       issue,question
# 146                                             port bug
# 149    easy,important,bug,docs,good first issue,optim...
# 152                                           bug report
# 156                                          enhancement
# 161    category: build/install,question (invalid trac...
# 162                                             area-mvc
# 165                           json protocol schema,large
# 168                        editor,severity/minor,type/ux
# 171                                                  bug
# 174    priority: high,status: in progress,type: enhan...
# 177                                          improvement
# 183            coverity,area: other,bug,priority: medium
# 184                                          all clients
# 185                                              feature
# 187                                     backend,data-reg
# 188                                          enhancement
# 190                                            type: bug
# 193                                       priority: high
# 194                                                  bug
# 195                                                unity
# 197                                           user story
# 200                                     ready for retest
# 201                                          enhancement
# 202                complexity/low,priority/high,type/bug
# 203                                            component
# 204                                                 code
# 205                                        packaging,bug
# 206                 assigned-to-author,client management
# 208                                             question
# 211                          area/monitoring,enhancement
# 213                                               fixed?
# 218                                             question
# 219                                  content,enhancement
# 220                                            component
# 221                                                 size
# 222          help wanted,needs refinestimation,pipelines
# 223                                                  bug
# 224                                         type.task,v.
# 225    gitchecking/third-repo,in-progress-queue,inpro...
# 227                                                 十分紧急
# 228                                      component: core
# 232                    - in review,feature specification
# 233                                          enhancement
# 234                 in:transport,release bug,team:sirius
# 235                                             ios,task
# 238                          enhancement,quality/release
# 239                                          enhancement
# 240                                          enhancement
# 242                   area/dashboard/templating,type/bug
# 243                                          enhancement
# 244                                              feature
# 245                                                front
# 248                                          enhancement
# 249    n: adguard browser extension,low,t: anti adblo...
# 251                           priority.medium,type.story
# 252                                                 size
# 253                                            usability
# 254                                             homework
# 255                                                   ui
# 258                                                  bug
# 259                               smart contracts,design
# 260                                 waiting for feedback
# 261                                             question
# 262                                      work: front-end
# 265                t - be enhancement,t - fe enhancement
# 266                                    enhancement,stale
# 267                             enhancement,needs review
# 268                                                  bug
# 269                                                  bug
# 270                  clt,júnior,pleno,presencial,inativa
# 275                   feat / lemmatizer,more-info-needed
# 278                                             question
# 279                                     discussion,stale
# 284                                          enhancement
# Name: try, dtype: object
